# %% [markdown]
# <a href="https://colab.research.google.com/github/madhavimali/PlayStore_DataDigger/blob/main/Play_Store_App_Review_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market. </b>
#
# ## <b> Each app (row) has values for catergory, rating, size, and more. Another dataset contains customer reviews of the android apps.</b>
#
# ## <b> Explore and analyze the data to discover key factors responsible for app engagement and success. </b>

# %%
# Import pandas package
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pip install colorama
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from colorama import Fore, Back, Style
print(Fore.BLUE, Back.YELLOW, Style.BRIGHT + 'Now we can get output i colour format.')
# Out:
#   Now we can get output i colour format.

# %%
from google.colab import data_table
data_table.enable_dataframe_formatter()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# loading csv File
file_path_1 = '/content/drive/MyDrive/Almabetter Access the data/Copy of Play Store Data.csv'
df_1 = pd.read_csv(file_path_1)
file_path_2 = '/content/drive/MyDrive/Almabetter Access the data/Copy of User Reviews.csv'
df_2 = pd.read_csv(file_path_2)

# %%
print('Shape of df_1 = ', df_1.shape, '\n')
df_1.head(2)
# Out:
# Shape of df_1 =  (10841, 13)
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
#data cleaning
newdf_1 = df_1.fillna(0)
newdf_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          10841 non-null  float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10841 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10841 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10841 non-null  object
#  12  Android Ver     10841 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
print('Shape of df_2 = ', df_2.shape, '\n')
df_2.head(2)
# Out:
# Shape of df_2 =  (64295, 5)
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462

# %%
newdf_2 = df_2.fillna(0)
newdf_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       64295 non-null  object
#  2   Sentiment               64295 non-null  object
#  3   Sentiment_Polarity      64295 non-null  float64
#  4   Sentiment_Subjectivity  64295 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %% [markdown]
# ### **Remove duplicates if any**

# %%
play_store_data = newdf_1.drop_duplicates()
play_store_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10358 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10358 non-null  object
#  1   Category        10358 non-null  object
#  2   Rating          10358 non-null  float64
#  3   Reviews         10358 non-null  object
#  4   Size            10358 non-null  object
#  5   Installs        10358 non-null  object
#  6   Type            10358 non-null  object
#  7   Price           10358 non-null  object
#  8   Content Rating  10358 non-null  object
#  9   Genres          10358 non-null  object
#  10  Last Updated    10358 non-null  object
#  11  Current Ver     10358 non-null  object
#  12  Android Ver     10358 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
user_reviews = newdf_2.drop_duplicates()
user_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30679 entries, 0 to 64236
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     30679 non-null  object
#  1   Translated_Review       30679 non-null  object
#  2   Sentiment               30679 non-null  object
#  3   Sentiment_Polarity      30679 non-null  float64
#  4   Sentiment_Subjectivity  30679 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 1.4+ MB

# %% [markdown]
# ### **For App column in play_store_data DataFrame**

# %%
print(play_store_data['App'].nunique())
play_store_data['App'].unique()
# Out:
# 9660
# array(['Photo Editor & Candy Camera & Grid & ScrapBook',
#        'Coloring book moana',
#        'U Launcher Lite – FREE Live Cool Themes, Hide Apps', ...,
#        'Parkinson Exercices FR', 'The SCP Foundation DB fr nn5n',
#        'iHoroscope - 2018 Daily Horoscope & Astrology'], dtype=object)

# %%
pd.DataFrame(play_store_data['App'].value_counts(ascending=True)).head(10)
# Out:
#                                                 App
# Photo Editor & Candy Camera & Grid & ScrapBook    1
# CK Call NEW                                       1
# Ck Coif                                           1
# CONTRACT KILLER: ZOMBIES                          1
# CK Shop                                           1
# FlexBook                                          1
# Can Knockdown 3                                   1
# INFAMY RO                                         1
# Fu*** Weather (Funny Weather)                     1
# CK Active                                         1

# %% [markdown]
# ### **For Category column in play_store_data DataFrame**

# %%
print(play_store_data['Category'].nunique())
play_store_data['Category'].unique()
# Out:
# 34
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
pd.DataFrame(play_store_data['Category'].value_counts(ascending=True)).head(10)
# Out:
#                     Category
# 1.9                        1
# BEAUTY                    53
# PARENTING                 60
# COMICS                    60
# EVENTS                    64
# ART_AND_DESIGN            65
# HOUSE_AND_HOME            80
# WEATHER                   82
# LIBRARIES_AND_DEMO        85
# AUTO_AND_VEHICLES         85

# %% [markdown]
# ### **For Rating column in play_store_data DataFrame**
# ****

# %%
print(play_store_data['Rating'].nunique())
play_store_data['Rating'].unique()
# Out:
# 41
# array([ 4.1,  3.9,  4.7,  4.5,  4.3,  4.4,  3.8,  4.2,  4.6,  3.2,  4. ,
#         0. ,  4.8,  4.9,  3.6,  3.7,  3.3,  3.4,  3.5,  3.1,  5. ,  2.6,
#         3. ,  1.9,  2.5,  2.8,  2.7,  1. ,  2.9,  2.3,  2.2,  1.7,  2. ,
#         1.8,  2.4,  1.6,  2.1,  1.4,  1.5,  1.2, 19. ])

# %%
pd.DataFrame(play_store_data['Rating'].value_counts(ascending=True)).head(10)
# Out:
#       Rating
# 19.0       1
# 1.2        1
# 1.4        3
# 1.5        3
# 1.6        4
# 2.1        8
# 1.8        8
# 1.7        8
# 2.0       12
# 1.9       12

# %% [markdown]
# ### **For Reviews column in play_store_data DataFrame**
# ****

# %%
print(play_store_data['Reviews'].nunique())
play_store_data['Reviews'].unique()
# Out:
# 6002
# array(['159', '967', '87510', ..., '603', '1195', '398307'], dtype=object)

# %%
pd.DataFrame(play_store_data['Reviews'].value_counts(ascending=True)).head(10)
# Out:
#         Reviews
# 413999        1
# 1564          1
# 2975          1
# 361734        1
# 346681        1
# 65766         1
# 1891          1
# 41624         1
# 55313         1
# 6750          1

# %% [markdown]
# ### **For Size column in play_store_data DataFrame**
# ****

# %%
print(play_store_data['Size'].nunique())
play_store_data['Size'].unique()
# Out:
# 462
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
pd.DataFrame(play_store_data['Size'].value_counts(ascending=True)).head(10)
# Out:
#       Size
# 371k     1
# 840k     1
# 186k     1
# 319k     1
# 683k     1
# 778k     1
# 569k     1
# 243k     1
# 613k     1
# 887k     1

# %% [markdown]
# ### **For Installs column in play_store_data DataFrame**
# ****

# %%
print(play_store_data['Installs'].nunique())
play_store_data['Installs'].unique()
# Out:
# 22
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0', 'Free'], dtype=object)

# %%
pd.DataFrame(play_store_data['Installs'].value_counts(ascending=True)).head(10)
# Out:
#                 Installs
# Free                   1
# 0                      1
# 0+                    14
# 1,000,000,000+        49
# 500,000,000+          61
# 1+                    67
# 5+                    82
# 50+                  204
# 50,000,000+          272
# 500+                 328

# %% [markdown]
# ### **For Type column in play_store_data DataFrame**
# ****

# %%
print(play_store_data['Type'].nunique())
play_store_data['Type'].unique()
# Out:
# 4
# array(['Free', 'Paid', 0, '0'], dtype=object)

# %%
pd.DataFrame(play_store_data['Type'].value_counts(ascending=True)).head(10)
# Out:
#       Type
# 0        1
# 0        1
# Paid   765
# Free  9591

# %% [markdown]
# ### **For Price column in play_store_data DataFrame**
# ****

# %%
print(play_store_data['Price'].nunique())
play_store_data['Price'].unique()
# Out:
# 93
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
pd.DataFrame(play_store_data['Price'].value_counts(ascending=True)).head(10)
# Out:
#          Price
# $1.61        1
# $2.59        1
# $3.08        1
# $154.99      1
# $109.99      1
# $46.99       1
# $4.85        1
# $14.00       1
# $1.75        1
# $4.80        1

# %% [markdown]
# ### **For Content Rating column in play_store_data DataFrame**
# ****

# %%
print(play_store_data['Content Rating'].nunique())
play_store_data['Content Rating'].unique()
# Out:
# 7
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated', 0], dtype=object)

# %%
pd.DataFrame(play_store_data['Content Rating'].value_counts(ascending=True)).head(10)
# Out:
#                  Content Rating
# 0                             1
# Unrated                       2
# Adults only 18+               3
# Everyone 10+                377
# Mature 17+                  447
# Teen                       1146
# Everyone                   8382

# %% [markdown]
# ### **For Genres column in play_store_data DataFrame**
# ****

# %%
print(play_store_data['Genres'].nunique())

play_store_data['Genres'].unique()
# Out:
# 120
# array(['Art & Design', 'Art & Design;Pretend Play',
#        'Art & Design;Creativity', 'Art & Design;Action & Adventure',
#        'Auto & Vehicles', 'Beauty', 'Books & Reference', 'Business',
#        'Comics', 'Comics;Creativity', 'Communication', 'Dating',
#        'Education;Education', 'Education', 'Education;Creativity',
#        'Education;Music & Video', 'Education;Action & Adventure',
#        'Education;Pretend Play', 'Education;Brain Games', 'Entertainment',
#        'Entertainment;Music & Video', 'Entertainment;Brain Games',
#        'Entertainment;Creativity', 'Events', 'Finance', 'Food & Drink',
#        'Health & Fitness', 'House & Home', 'Libraries & Demo',
#        'Lifestyle', 'Lifestyle;Pretend Play',
#        'Adventure;Action & Adventure', 'Arcade', 'Casual', 'Card',
#        'Casual;Pretend Play', 'Action', 'Strategy', 'Puzzle', 'Sports',
#        'Music', 'Word', 'Racing', 'Casual;Creativity',
# ...

# %%
pd.DataFrame(play_store_data['Genres'].value_counts(ascending=True)).head(10)
# Out:
#                                    Genres
# Strategy;Creativity                     1
# Entertainment;Education                 1
# February 11, 2018                       1
# Card;Brain Games                        1
# Music & Audio;Music & Video             1
# Health & Fitness;Education              1
# Board;Pretend Play                      1
# Casual;Music & Video                    1
# Lifestyle;Pretend Play                  1
# Travel & Local;Action & Adventure       1

# %% [markdown]
# ### **For Last Update column in play_store_data DataFrame**
# ****

# %%
print(play_store_data['Last Updated'].nunique())

play_store_data['Last Updated'].unique()
# Out:
# 1378
# array(['January 7, 2018', 'January 15, 2018', 'August 1, 2018', ...,
#        'January 20, 2014', 'February 16, 2014', 'March 23, 2014'],
#       dtype=object)

# %%
pd.DataFrame(play_store_data['Last Updated'].value_counts(ascending=True)).head(10)
# Out:
#                     Last Updated
# March 23, 2014                 1
# February 20, 2016              1
# April 13, 2014                 1
# September 13, 2013             1
# August 14, 2013                1
# April 22, 2013                 1
# June 9, 2014                   1
# August 18, 2012                1
# September 6, 2014              1
# October 16, 2015               1

# %% [markdown]
# ### **For Current Ver column in play_store_data DataFrame**
# ****

# %%
print(play_store_data['Current Ver'].nunique())
play_store_data['Current Ver']
# Out:
# 2833
# 0                     1.0.0
# 1                     2.0.0
# 2                     1.2.4
# 3        Varies with device
# 4                       1.1
#                 ...
# 10836                  1.48
# 10837                   1.0
# 10838                   1.0
# 10839    Varies with device
# 10840    Varies with device
# Name: Current Ver, Length: 10358, dtype: object

# %%
pd.DataFrame(play_store_data['Current Ver'].value_counts(ascending=True)).head(10)
# Out:
#                         Current Ver
# 5.1.0 free                        1
# 20180620                          1
# 1.0.0.8                           1
# 1.11.39                           1
# 5.17.2.009                        1
# 3.1.0 (build 1210)                1
# 18.6.2                            1
# 4.05                              1
# Z (Special Edition R9)            1
# 1.85                              1

# %% [markdown]
# ### **For Android Ver column in play_store_data DataFrame**
# ****

# %%
print(play_store_data['Android Ver'].nunique())
play_store_data['Android Ver'].unique()
# Out:
# 34
# array(['4.0.3 and up', '4.2 and up', '4.4 and up', '2.3 and up',
#        '3.0 and up', '4.1 and up', '4.0 and up', '2.3.3 and up',
#        'Varies with device', '2.2 and up', '5.0 and up', '6.0 and up',
#        '1.6 and up', '1.5 and up', '2.1 and up', '7.0 and up',
#        '5.1 and up', '4.3 and up', '4.0.3 - 7.1.1', '2.0 and up',
#        '3.2 and up', '4.4W and up', '7.1 and up', '7.0 - 7.1.1',
#        '8.0 and up', '5.0 - 8.0', '3.1 and up', '2.0.1 and up',
#        '4.1 - 7.1.1', 0, '5.0 - 6.0', '1.0 and up', '2.2 - 7.1.1',
#        '5.0 - 7.1.1'], dtype=object)

# %%
pd.DataFrame(play_store_data['Android Ver'].value_counts(ascending=True)).head(10)
# Out:
#                Android Ver
# 5.0 - 7.1.1              1
# 5.0 - 6.0                1
# 4.1 - 7.1.1              1
# 7.0 - 7.1.1              1
# 2.2 - 7.1.1              1
# 1.0 and up               2
# 5.0 - 8.0                2
# 4.0.3 - 7.1.1            2
# 0                        3
# 7.1 and up               3

# %%
play_store_data.describe(include='all')
# Out:
#            App Category        Rating Reviews                Size    Installs  \
# count    10358    10358  10358.000000   10358               10358       10358
# unique    9660       34           NaN    6002                 462          22
# top     ROBLOX   FAMILY           NaN       0  Varies with device  1,000,000+
# freq         9     1943           NaN     593                1526        1488
# mean       NaN      NaN      3.596988     NaN                 NaN         NaN
# std        NaN      NaN      1.545008     NaN                 NaN         NaN
# min        NaN      NaN      0.000000     NaN                 NaN         NaN
# 25%        NaN      NaN      3.700000     NaN                 NaN         NaN
# 50%        NaN      NaN      4.200000     NaN                 NaN         NaN
# 75%        NaN      NaN      4.500000     NaN                 NaN         NaN
# max        NaN      NaN     19.000000     NaN                 NaN         NaN
#
# ...

# %%
user_reviews.describe(include='all')
# Out:
#              App  Translated_Review Sentiment  Sentiment_Polarity  \
# count      30679            30679.0     30679        30679.000000
# unique      1074            27995.0         4                 NaN
# top     Facebook                0.0  Positive                 NaN
# freq         131              987.0     19015                 NaN
# mean         NaN                NaN       NaN            0.182792
# std          NaN                NaN       NaN            0.351508
# min          NaN                NaN       NaN           -1.000000
# 25%          NaN                NaN       NaN            0.000000
# 50%          NaN                NaN       NaN            0.142857
# 75%          NaN                NaN       NaN            0.409212
# max          NaN                NaN       NaN            1.000000
#
#         Sentiment_Subjectivity
# count             30679.000000
# unique                     NaN
# top                        NaN
# freq                       NaN
# ...

# %%
print(Fore.MAGENTA + 'Total number of application in play store data', len(play_store_data))
print(Fore.GREEN + 'Total number of application in user review data', len(user_reviews))
# Out:
# Total number of application in play store data 10358
# Total number of application in user review data 30679

# %%
play_store_data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
a = play_store_data['Type'].value_counts()['Free']
b = play_store_data['Type'].value_counts()['Paid']
print(a)
print(b)
# Out:
# 9591
# 765

# %%
#creating datasets
parts = ['Paid', 'Free']
data = [a, b]

# #creating explode data
# explode = (0.0,0.1)

# # creating copour parameter
# colours = ("Cornflower blue", "Alice blue")

# Creating plot
fig = plt.figure(figsize =(10, 7))
plt.pie(data, labels = parts)
 
# show plot
plt.show()

# %%
# creating datasets
labels = ['Paid', 'Free']
data = [a, b]

# creating explode data
explode = (0.1,0.1)

# creating copour parameter
colours = ("Magenta", "Cyan")

# Wedge properties
wp = { 'linewidth' : 1, 'edgecolor' : "White" }

# Creating autocpt arguments
def func(percentage, allvalues):
    absolute = int(percentage / 100.*np.sum(allvalues))
    return "{:.2f}%\n({:d} apps)".format(percentage, absolute)
 
# Creating plot
fig, ax = plt.subplots(figsize =(10, 7))
wedges, texts, autotexts = ax.pie(data,
                                  autopct = lambda percentage: func(percentage, data),
                                  explode = explode,
                                  labels = labels,
                                  shadow = True,
                                  colors = colours,
                                  startangle = 60,
                                  wedgeprops = wp,
                                  textprops = dict(color ="Black"))
 
# Adding legend
ax.legend(wedges, labels,
          title ="Pie Chart",
          loc ="center left",
          bbox_to_anchor =(1, 0, 0.5, 1))
 
plt.setp(autotexts, size = 12, weight ="bold")
ax.set_title("Customizing pie chart")
 
# show plot
plt.tight_layout()
